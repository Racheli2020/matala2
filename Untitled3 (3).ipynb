# %%
import pandas as pd
from datetime import datetime

data = pd.read_csv("C:\\Users\\rache\\OneDrive\\שולחן העבודה\\matala2_cosmetics_2019-Nov.csv", low_memory=False)
# Out:
#                  event_time        event_type  product_id  \
# 0   2019-11-01 00:00:02 UTC              view     5802432
# 1   2019-11-01 00:00:09 UTC              cart     5844397
# 2   2019-11-01 00:00:10 UTC              view     5837166
# 3   2019-11-01 00:00:11 UTC              cart     5876812
# 4   2019-11-01 00:00:24 UTC  remove_from_cart     5826182
# 5   2019-11-01 00:00:24 UTC  remove_from_cart     5826182
# 6   2019-11-01 00:00:25 UTC              view     5856189
# 7   2019-11-01 00:00:32 UTC              view     5837835
# 8   2019-11-01 00:00:34 UTC  remove_from_cart     5870838
# 9   2019-11-01 00:00:37 UTC              view     5870803
# 10  2019-11-01 00:00:42 UTC  remove_from_cart     5870803
# 11  2019-11-01 00:00:46 UTC              view     5841721
# 12  2019-11-01 00:00:50 UTC              view     5856190
# 13  2019-11-01 00:00:51 UTC  remove_from_cart     5710314
# 14  2019-11-01 00:00:55 UTC              view        5534
#
# ...

# %%
# Out:
#                    event_time        event_type  product_id  \
# 0     2019-11-01 00:00:02 UTC              view     5802432
# 1     2019-11-01 00:00:09 UTC              cart     5844397
# 2     2019-11-01 00:00:10 UTC              view     5837166
# 3     2019-11-01 00:00:11 UTC              cart     5876812
# 4     2019-11-01 00:00:24 UTC  remove_from_cart     5826182
# ...                       ...               ...         ...
# 1995  2019-11-01 02:01:58 UTC              view        5528
# 1996  2019-11-01 02:02:07 UTC  remove_from_cart     5883637
# 1997  2019-11-01 02:02:07 UTC  remove_from_cart     5883637
# 1998  2019-11-01 02:02:13 UTC              cart     5655060
# 1999  2019-11-01 02:02:15 UTC  remove_from_cart     5739493
#
#               category_id category_code     brand  price    user_id  \
# 0     1487580009286598681           NaN       NaN   0.32  562076640
# 1     1487580006317032337           NaN       NaN   2.38  553329724
# ...

# %%
#rewrite the code so it calculate the time difference between events only if o they belong to the same user_session values.

# %% [markdown]
# # Q1

# %%
#the code##########################
from datetime import datetime
data.loc[:, 'event_time'] = pd.to_datetime(data['event_time'])

data = data.sort_values(by=['user_session', 'event_time'])

x = data['user_session'] == data['user_session'].shift(1)
if x.all():
    date1 = data['event_time'].str.split()
    hour1 = date1.str[1]
    datetime1 = datetime.strptime(hour1, '%H:%M:%S')
    
    date2 = data['event_time'].shift(1).str.split()
    hour2 = date2.str[1]
    datetime2 = datetime.strptime(hour2, '%H:%M:%S')
    
    time_diff = datetime2 - datetime1

data['duration_to_next_event1'] = (data.groupby('user_session')['event_time'].shift(-1) - data['event_time']).dt.total_seconds().fillna(0)
    
#data2['duration_from_previous_event'] = (data2['event_time'] - data.groupby('user_session')['event_time'].shift()).dt.total_seconds().fillna(0)

#data2['duration_to_next_event'] = data2.groupby('user_session')['event_time'].diff().dt.total_seconds().fillna(0)

data
# Out:
# c:\users\rache\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#                     event_time event_type  product_id          category_id  \
# 1468 2019-11-01 01:35:21+00:00       view        4765  1487580010796548183
# 953  2019-11-01 01:03:35+00:00       view     5696324  1487580013841613016
# 1338 2019-11-01 01:28:13+00:00       view     5815157  1487580005461394279
# 926  2019-11-01 01:00:57+00:00       view     5899436  1487580010268065854
# 508  2019-11-01 00:38:39+00:00       view     5670001  1495705810662064688
# ...                        ...        ...         ...                  ...
# ...

# %%
data2
# Out:
#                     event_time event_type  product_id          category_id  \
# 1468 2019-11-01 01:35:21+00:00       view        4765  1487580010796548183
# 953  2019-11-01 01:03:35+00:00       view     5696324  1487580013841613016
# 1338 2019-11-01 01:28:13+00:00       view     5815157  1487580005461394279
# 926  2019-11-01 01:00:57+00:00       view     5899436  1487580010268065854
# 508  2019-11-01 00:38:39+00:00       view     5670001  1495705810662064688
# ...                        ...        ...         ...                  ...
# 1269 2019-11-01 01:24:54+00:00       cart     5823014  1487580008246412266
# 1270 2019-11-01 01:24:57+00:00       cart     5823014  1487580008246412266
# 1274 2019-11-01 01:25:02+00:00       view     5823014  1487580008246412266
# 1289 2019-11-01 01:26:01+00:00       cart     5677054  1487580008246412266
# 1926 2019-11-01 01:57:09+00:00       cart     5850494  1487580008246412266
#
#      category_code    brand  price    user_id  \
# ...

# %% [markdown]
# # Q2 WORKING

# %%
#working q2

from datetime import datetime, timedelta

data.loc[:, 'event_time'] = pd.to_datetime(data['event_time'])

data = data.sort_values(by=['user_session', 'event_time'])

def calculate_funnel_number(group):
    event1 = group['event_time'].iloc[0]
    event2 = group['event_time'].shift(1).iloc[0]
    time_diff = event1 - event2
    if time_diff.days <= 5:
        return 1
    else:
        time_diffs = (group['event_time'] - group['event_time'].shift(1)).dt.days.fillna(0)
        time_diffs.loc[time_diffs > 5] = 1
        return time_diffs.cumsum() + 1

data['funnel_number'] = data.groupby('user_session').apply(calculate_funnel_number).reset_index(drop=True)

data

# %% [markdown]
# # Q3 WORKING

# %%
from datetime import datetime, timedelta

data.loc[:, 'event_time'] = pd.to_datetime(data['event_time'])

data = data.sort_values(by=['user_session', 'event_time'])

def calculate_funnel_number(group):
    event1 = group['event_time'].iloc[0]
    event2 = group['event_time'].shift(1).iloc[0]
    time_diff = event1 - event2
    if time_diff.days <= 5:
        return 1
    else:
        time_diffs = (group['event_time'] - group['event_time'].shift(1)).dt.days.fillna(0)
        time_diffs.loc[time_diffs > 5] = 1
        return time_diffs.cumsum() + 1

data['funnel_number'] = data.groupby('user_session').apply(calculate_funnel_number).reset_index(drop=True)

data['index_in_funnel'] = data.groupby(['user_session', 'funnel_number']).cumcount() + 1

data
# Out:
#                     event_time event_type  product_id          category_id  \
# 1468 2019-11-01 01:35:21+00:00       view        4765  1487580010796548183
# 953  2019-11-01 01:03:35+00:00       view     5696324  1487580013841613016
# 1338 2019-11-01 01:28:13+00:00       view     5815157  1487580005461394279
# 926  2019-11-01 01:00:57+00:00       view     5899436  1487580010268065854
# 508  2019-11-01 00:38:39+00:00       view     5670001  1495705810662064688
# ...                        ...        ...         ...                  ...
# 1269 2019-11-01 01:24:54+00:00       cart     5823014  1487580008246412266
# 1270 2019-11-01 01:24:57+00:00       cart     5823014  1487580008246412266
# 1274 2019-11-01 01:25:02+00:00       view     5823014  1487580008246412266
# 1289 2019-11-01 01:26:01+00:00       cart     5677054  1487580008246412266
# 1926 2019-11-01 01:57:09+00:00       cart     5850494  1487580008246412266
#
#      category_code    brand  price    user_id  \
# ...

# %% [markdown]
# # #Q4

# %%
def extract_float(text):
    try:
        return float(re.findall(r'\d+\.?\d*', str(text))[0])
    except:
        return text

data['price'] = data['price'].apply(extract_float)


data
# Out:
#                     event_time event_type  product_id          category_id  \
# 1468 2019-11-01 01:35:21+00:00       view        4765  1487580010796548183
# 953  2019-11-01 01:03:35+00:00       view     5696324  1487580013841613016
# 1338 2019-11-01 01:28:13+00:00       view     5815157  1487580005461394279
# 926  2019-11-01 01:00:57+00:00       view     5899436  1487580010268065854
# 508  2019-11-01 00:38:39+00:00       view     5670001  1495705810662064688
# ...                        ...        ...         ...                  ...
# 1269 2019-11-01 01:24:54+00:00       cart     5823014  1487580008246412266
# 1270 2019-11-01 01:24:57+00:00       cart     5823014  1487580008246412266
# 1274 2019-11-01 01:25:02+00:00       view     5823014  1487580008246412266
# 1289 2019-11-01 01:26:01+00:00       cart     5677054  1487580008246412266
# 1926 2019-11-01 01:57:09+00:00       cart     5850494  1487580008246412266
#
#      category_code    brand  price    user_id  \
# ...

# %% [markdown]
# # Q5

# %%
import matplotlib.pyplot as plt


event_counts = data.groupby('event_type').count()['event_time']

plt.bar(event_counts.index, event_counts.values)
plt.title('Number of events by event type')
plt.xlabel('Event type')
plt.ylabel('Number of events')
plt.show()

# %% [markdown]
# # 6

# %%
aggregations = {
    'event_time': 'min',
    'duration_to_next_event1': 'mean',
    'duration_to_next_event1': 'max',
    'product_id': lambda x: list(x),
    'category_id': lambda x: list(x),
    'category_code': lambda x: list(x),
    'brand': lambda x: list(x),
    'price': lambda x: list(x),
}

session_data = data.groupby(['user_id', 'user_session']).agg(aggregations).reset_index()

session_data.columns = ['user_id', 'user_session', 'first_event_time', 'avg_duration_to_next_event', 'max_session_duration',                         'product_id_list', 'category_id_list', 'category_code_list', 'brand_list', 'price_list']

session_data['first_event_time'] = pd.to_datetime(session_data['first_event_time'])

session_data['max_session_duration'] = (session_data['max_session_duration'] - session_data['first_event_time']).dt.total_seconds()
